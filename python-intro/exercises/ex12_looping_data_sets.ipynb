# %% [markdown]
# # Exercise 12: Looping Over Data Sets

# %% [markdown]
# ## Aim: Use `glob` to find sets of files, and write loops to perform operations on files.

# %% [markdown]
# ### Issues covered:
# - Using a `for` loop to loop over a given list of files
# - Using `glob` to match patterns of files
# - Looping over sets of files using `glob`
# - Using `glob` and `for` to process data from mutliple files

# %% [markdown]
# ## 1. Looping over files from a simple list

# %% [markdown]
# Use a `for` loop to loop over the files in the data folder (americas_gdp.csv, europe_gdp.csv and oceania_gdp.csv) and print out the maxima of the datasets.

# %%
import glob
import pandas as pd

for file in glob.glob('data/*_gdp.csv'):
    df=pd.read_csv(file, index_col='country')
    print(pd.DataFrame([df.idxmax(), df.max()]).T)
# Out:
#                           0            1
# gdpPercap_1952  New Zealand  10556.57566
# gdpPercap_1957  New Zealand  12247.39532
# gdpPercap_1962  New Zealand    13175.678
# gdpPercap_1967    Australia  14526.12465
# gdpPercap_1972    Australia  16788.62948
# gdpPercap_1977    Australia  18334.19751
# gdpPercap_1982    Australia  19477.00928
# gdpPercap_1987    Australia  21888.88903
# gdpPercap_1992    Australia  23424.76683
# gdpPercap_1997    Australia  26997.93657
# gdpPercap_2002    Australia  30687.75473
# gdpPercap_2007    Australia  34435.36744
#                           0            1
# gdpPercap_1952  Switzerland  14734.23275
# gdpPercap_1957  Switzerland  17909.48973
# gdpPercap_1962  Switzerland   20431.0927
# gdpPercap_1967  Switzerland  22966.14432
# gdpPercap_1972  Switzerland  27195.11304
# gdpPercap_1977  Switzerland  26982.29052
# gdpPercap_1982  Switzerland  28397.71512
# gdpPercap_1987       Norway   31540.9748
# gdpPercap_1992       Norway  33965.66115
# gdpPercap_1997       Norway  41283.16433
# gdpPercap_2002       Norway  44683.97525
# gdpPercap_2007       Norway  49357.19017
#                             0            1
# continent           Argentina     Americas
# gdpPercap_1952  United States  13990.48208
# gdpPercap_1957  United States  14847.12712
# gdpPercap_1962  United States  16173.14586
# gdpPercap_1967  United States  19530.36557
# gdpPercap_1972  United States  21806.03594
# gdpPercap_1977  United States  24072.63213
# gdpPercap_1982  United States  25009.55914
# gdpPercap_1987  United States  29884.35041
# gdpPercap_1992  United States  32003.93224
# gdpPercap_1997  United States  35767.43303
# gdpPercap_2002  United States  39097.09955
# gdpPercap_2007  United States  42951.65309
#                             0            1
# Unnamed: 0          Venezuela           24
# continent           Argentina     Americas
# gdpPercap_1952  United States  13990.48208
# gdpPercap_1957  United States  14847.12712
# gdpPercap_1962  United States  16173.14586
# gdpPercap_1967  United States  19530.36557
# gdpPercap_1972  United States  21806.03594
# gdpPercap_1977  United States  24072.63213
# gdpPercap_1982  United States  25009.55914
# gdpPercap_1987  United States  29884.35041
# gdpPercap_1992  United States  32003.93224
# gdpPercap_1997  United States  35767.43303
# gdpPercap_2002  United States  39097.09955
# gdpPercap_2007  United States  42951.65309

# %% [markdown]
# ## 2. Using `glob` to loop through files

# %% [markdown]
# What do you think `glob.glob('*.ipynb')` will return? Try it and see.

# %%
glob.glob('*.ipynb')
# Out:
# ['ex02_variables_assignment.ipynb',
#  'ex03_data_types.ipynb',
#  'ex09_lists.ipynb',
#  'ex04_built_in_functions.ipynb',
#  'ex11_conditionals.ipynb',
#  'ex01_running_notebooks.ipynb',
#  'ex15_programming_style.ipynb',
#  'ex10_for_loops.ipynb',
#  'ex14_variable_scope.ipynb',
#  'ex05_libraries.ipynb',
#  'ex06_dataframes.ipynb',
#  'ex07_pandas_dataframes.ipynb',
#  'ex16_wrap_up.ipynb',
#  'ex12_looping_data_sets.ipynb',
#  'ex08_plotting.ipynb',
#  'ex13_writing_functions.ipynb']

# %% [markdown]
# How can we return only the files for exercises 1-9?

# %%
glob.glob('ex0*.ipynb')
# Out:
# ['ex02_variables_assignment.ipynb',
#  'ex03_data_types.ipynb',
#  'ex09_lists.ipynb',
#  'ex04_built_in_functions.ipynb',
#  'ex01_running_notebooks.ipynb',
#  'ex05_libraries.ipynb',
#  'ex06_dataframes.ipynb',
#  'ex07_pandas_dataframes.ipynb',
#  'ex08_plotting.ipynb']

# %% [markdown]
# Which exercises have coffee in their title?

# %% [markdown]
# ## 3. Using `glob` and `for` to process files

# %% [markdown]
# Write a `for` loop which loops through all of the files containing `gdp` in the title, write the data to a dataframe, then print the dataframe minimum for all columns (using `.min()`).
