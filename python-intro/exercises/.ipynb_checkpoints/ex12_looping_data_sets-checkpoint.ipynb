# %% [markdown]
# # Exercise 12: Looping Over Data Sets

# %% [markdown]
# ## Aim: Use `glob` to find sets of files, and write loops to perform operations on files.

# %% [markdown]
# ### Issues covered:
# - Using a `for` loop to loop over a given list of files
# - Using `glob` to match patterns of files
# - Looping over sets of files using `glob`
# - Using `glob` and `for` to process data from mutliple files

# %% [markdown]
# ## 1. Looping over files from a simple list

# %% [markdown]
# Use a `for` loop to loop over the files in the data folder (americas_gdp.csv, europe_gdp.csv and oceania_gdp.csv) and print out the maxima of the datasets.

# %%
import glob
import pandas as pd

for file in glob.glob('data/*_gdp.csv'):
    df=pd.read_csv(file, index_col='country')
    print(f"{file} {df.max()} {df.idxmax()}")
# Out:
# data/oceania_gdp.csv gdpPercap_1952    10556.57566
# gdpPercap_1957    12247.39532
# gdpPercap_1962    13175.67800
# gdpPercap_1967    14526.12465
# gdpPercap_1972    16788.62948
# gdpPercap_1977    18334.19751
# gdpPercap_1982    19477.00928
# gdpPercap_1987    21888.88903
# gdpPercap_1992    23424.76683
# gdpPercap_1997    26997.93657
# gdpPercap_2002    30687.75473
# gdpPercap_2007    34435.36744
# dtype: float64 gdpPercap_1952    New Zealand
# gdpPercap_1957    New Zealand
# gdpPercap_1962    New Zealand
# gdpPercap_1967      Australia
# gdpPercap_1972      Australia
# gdpPercap_1977      Australia
# gdpPercap_1982      Australia
# gdpPercap_1987      Australia
# gdpPercap_1992      Australia
# gdpPercap_1997      Australia
# gdpPercap_2002      Australia
# gdpPercap_2007      Australia
# dtype: object
# data/europe_gdp.csv gdpPercap_1952    14734.23275
# gdpPercap_1957    17909.48973
# gdpPercap_1962    20431.09270
# gdpPercap_1967    22966.14432
# gdpPercap_1972    27195.11304
# gdpPercap_1977    26982.29052
# gdpPercap_1982    28397.71512
# gdpPercap_1987    31540.97480
# gdpPercap_1992    33965.66115
# gdpPercap_1997    41283.16433
# gdpPercap_2002    44683.97525
# gdpPercap_2007    49357.19017
# dtype: float64 gdpPercap_1952    Switzerland
# gdpPercap_1957    Switzerland
# gdpPercap_1962    Switzerland
# gdpPercap_1967    Switzerland
# gdpPercap_1972    Switzerland
# gdpPercap_1977    Switzerland
# gdpPercap_1982    Switzerland
# gdpPercap_1987         Norway
# gdpPercap_1992         Norway
# gdpPercap_1997         Norway
# gdpPercap_2002         Norway
# gdpPercap_2007         Norway
# dtype: object
# data/americas_gdp.csv continent            Americas
# gdpPercap_1952    13990.48208
# gdpPercap_1957    14847.12712
# gdpPercap_1962    16173.14586
# gdpPercap_1967    19530.36557
# gdpPercap_1972    21806.03594
# gdpPercap_1977    24072.63213
# gdpPercap_1982    25009.55914
# gdpPercap_1987    29884.35041
# gdpPercap_1992    32003.93224
# gdpPercap_1997    35767.43303
# gdpPercap_2002    39097.09955
# gdpPercap_2007    42951.65309
# dtype: object continent             Argentina
# gdpPercap_1952    United States
# gdpPercap_1957    United States
# gdpPercap_1962    United States
# gdpPercap_1967    United States
# gdpPercap_1972    United States
# gdpPercap_1977    United States
# gdpPercap_1982    United States
# gdpPercap_1987    United States
# gdpPercap_1992    United States
# gdpPercap_1997    United States
# gdpPercap_2002    United States
# gdpPercap_2007    United States
# dtype: object
# data/saving_trial_americas_gdp.csv Unnamed: 0                 24
# continent            Americas
# gdpPercap_1952    13990.48208
# gdpPercap_1957    14847.12712
# gdpPercap_1962    16173.14586
# gdpPercap_1967    19530.36557
# gdpPercap_1972    21806.03594
# gdpPercap_1977    24072.63213
# gdpPercap_1982    25009.55914
# gdpPercap_1987    29884.35041
# gdpPercap_1992    32003.93224
# gdpPercap_1997    35767.43303
# gdpPercap_2002    39097.09955
# gdpPercap_2007    42951.65309
# dtype: object Unnamed: 0            Venezuela
# continent             Argentina
# gdpPercap_1952    United States
# gdpPercap_1957    United States
# gdpPercap_1962    United States
# gdpPercap_1967    United States
# gdpPercap_1972    United States
# gdpPercap_1977    United States
# gdpPercap_1982    United States
# gdpPercap_1987    United States
# gdpPercap_1992    United States
# gdpPercap_1997    United States
# gdpPercap_2002    United States
# gdpPercap_2007    United States
# dtype: object

# %%
df = pd.read_csv('data/americas_gdp.csv')
df.set_index('country', inplace=True)

# %%
pd.DataFrame([df.idxmax(), df.max()]).T
# Out:
#                             0            1
# continent           Argentina     Americas
# gdpPercap_1952  United States  13990.48208
# gdpPercap_1957  United States  14847.12712
# gdpPercap_1962  United States  16173.14586
# gdpPercap_1967  United States  19530.36557
# gdpPercap_1972  United States  21806.03594
# gdpPercap_1977  United States  24072.63213
# gdpPercap_1982  United States  25009.55914
# gdpPercap_1987  United States  29884.35041
# gdpPercap_1992  United States  32003.93224
# gdpPercap_1997  United States  35767.43303
# gdpPercap_2002  United States  39097.09955
# gdpPercap_2007  United States  42951.65309

# %% [markdown]
# ## 2. Using `glob` to loop through files

# %% [markdown]
# What do you think `glob.glob('*.ipynb')` will return? Try it and see.

# %% [markdown]
# How can we return only the files for exercises 1-9?

# %% [markdown]
# Which exercises have coffee in their title?

# %% [markdown]
# ## 3. Using `glob` and `for` to process files

# %% [markdown]
# Write a `for` loop which loops through all of the files containing `gdp` in the title, write the data to a dataframe, then print the dataframe minimum for all columns (using `.min()`).
